# %% [markdown]
# # Линейная алгебра, математический анализ

# %% [markdown]
# *1. Даны матрицы:*
#
# $$
# \begin{align*}
# &\mathbf{A} = \begin{vmatrix}
# 2 & -4 \\
# 3 & 5 \\
# -1 & 0
# \end{vmatrix}, \quad
# \mathbf{B} = \begin{vmatrix}
# 1 & 2 & 7 \\
# -3 & -4 & 0 \\
# 5 & 2 & 1
# \end{vmatrix}, \quad
# \mathbf{C} = \begin{vmatrix}
# 6 & -3 & 9 \\
# 4 & -5 & 2 \\
# 8 & 1 & 5
# \end{vmatrix}
# \end{align*}
# $$
#
# *Посчитайте матрицу* $D = A^T C - 2A^T B^T$. *Приведите полную последовательность вычислений.*

# %% [markdown]
# *Решение:*
#
# $ \\[1em]D = A^T C - 2A^T B^T
# = \begin{vmatrix}
# 2 & 3 & -1\\
# -4 & 5 & 0
# \end{vmatrix}
# \quad\cdot\quad\begin{vmatrix}
# 6 & -3 & 9 \\
# 4 & -5 & 2 \\
# 8 & 1 & 5
# \end{vmatrix}
# \quad-\quad 2\quad\cdot\quad\begin{vmatrix}
# 2 & 3 & -1\\
# -4 & 5 & 0
# \end{vmatrix}
# \quad\cdot\quad\begin{vmatrix}
# 1 & -3 & 5 \\
# 2 & -4 & 2 \\
# 7 & 0 & 1
# \end{vmatrix}
# \quad=\quad
# \\[1em]
# $
#
# $
# =\quad\begin{vmatrix}
# 2 \cdot 6 + 3 \cdot 4 + (-1) \cdot 8 & 2 \cdot (-3) + 3 \cdot (-5) + (-1) \cdot 1 & 2 \cdot 9 + 3 \cdot 2 + (-1) \cdot 5\\
# -4 \cdot 6 + 5 \cdot 4 + 0 \cdot 8 & -4 \cdot (-3) + 5 \cdot (-5) + 0 \cdot 1 & -4 \cdot 9 + 5 \cdot 2 + 0 \cdot 5
# \end{vmatrix}
# \quad-\quad
# \\[1em]
# $
#
# $
# -\quad\begin{vmatrix}
# 2(2 \cdot 1 + 3 \cdot 2 + (-1) \cdot 7) & 2(2 \cdot (-3) + 3 \cdot (-4) + (-1) \cdot 0) & 2(2 \cdot 5 + 3 \cdot 2 + (-1) \cdot 1)\\
# 2((-4) \cdot 1 + 5 \cdot 2 + 0 \cdot 7) & 2((-4) \cdot (-3) + 5 \cdot (-4) + 0 \cdot 0) & 2((-4) \cdot 5 + 5 \cdot 2 + 0 \cdot 1)
# \end{vmatrix}
# \quad=\quad
# \\[1em]
# $
#
# $
# =\quad\begin{vmatrix}
# 16 & -22 & 19\\
# -4 & -13 & -26
# \end{vmatrix}
# \quad-\quad\begin{vmatrix}
# 2 & -36 & 30\\
# 12 & -16 & -20
# \end{vmatrix}
# \quad=\quad\begin{vmatrix}
# 14 & 14 & -11\\
# -16 & 3 & -6
# \end{vmatrix}$

# %% [markdown]
# *2. Дано выражение:*
#
# $$
# \begin{align*}
# 3\quad\cdot\quad\begin{vmatrix}
# x & 2 & 3 \\
# -1 & y & 4
# \end{vmatrix}
# \quad+\quad 2\quad\cdot\quad\begin{vmatrix}
# 1 & 2 & -5 \\
# 2 & -6 & z
# \end{vmatrix}
# \quad=\quad\begin{vmatrix}
# 8 & v & -1 \\
# 1 & 6 & 4
# \end{vmatrix}
# \end{align*}
# $$
#
# *Найдите значение*$\, x,\, y,\, z\,$ *и* $\, v,\,$ *при которых выражение верно.*

# %% [markdown]
# *Решение:*
#
# $
# 3\quad\cdot\quad\begin{vmatrix}
# x & 2 & 3 \\
# -1 & y & 4
# \end{vmatrix}
# \quad+\quad 2\quad\cdot\quad\begin{vmatrix}
# 1 & 2 & -5 \\
# 2 & -6 & z
# \end{vmatrix}
# \quad=\quad\begin{vmatrix}
# 8 & v & -1 \\
# 1 & 6 & 4
# \end{vmatrix}
# \quad;\quad
# \\[1em]
# $
#
# $
# \begin{vmatrix}
# 3x & 6 & 9 \\
# -3 & 3y & 12
# \end{vmatrix}
# \quad+\quad\begin{vmatrix}
# 2 & 4 & -10 \\
# 4 & -12 & 2z
# \end{vmatrix}
# \quad-\quad\begin{vmatrix}
# 8 & v & -1 \\
# 1 & 6 & 4
# \end{vmatrix}
# \quad=\quad 0
# \quad;\quad
# \\[1em]
# $
#
# $
# \begin{vmatrix}
# 3x+2-8 & 6+4-v & 9-10+1 \\
# -3+4-1 & 3y-12-6 & 12+2z-4
# \end{vmatrix}
# \quad=\quad 0
# \quad;\quad
# \\[1em]
# $
#
# $
# \begin{vmatrix}
# 3x-6 & 10-v & 0 \\
# 0 & 3y-18 &2z+8
# \end{vmatrix}
# \quad=\quad 0
# \quad;\quad
# \\[1em]
# $
#
# $
# \begin{cases}
# 3x-6=0\\
# 10-v=0\\
# 3y-18=0\\
# 2z+8=0
# \end{cases}
# \quad;\quad
# \\[1em]
# $
#
# $
# \begin{cases}
# x=2\\
# v=10\\
# y=6\\
# z=-4
# \end{cases}
# $
